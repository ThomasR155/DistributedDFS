# %% [markdown]
# # Semester Project in Distributed Algorithms by Raphael Duarte and Thomas Riedl
#
# ## Implementation of Distributed Depth-First-Search with gRPC and Docker

# %%
import yaml
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
#own module
import dfs_containerization as dfs_con
import subprocess


# specify the graph of distributed nodes with edge list, all used nodes will be part of the graph
edge_list = [[1,7], [1,2], [1,4], [1,6],
             [2,1], [2,4], [2,3],
             [3,2], [3,4], [3,6], [3,5], [3,7], [3,8], [3,10],
             [4,1], [4,2], [4,3],[4,6], 
             [5,1], [5,3], [5,7],
             [6,4], [6,3], [6,10],
             [7,5], [7,3], [7,8],
             [8,3], [8,7],
             [10,3],[10,6]]

# %%
#plot the input graph
dfs_con.plot_input_graph(edge_list)

# %%
# create an overview of neigbours for each node of the graph and save result as "neighbours.yml"
dfs_con.get_neigbours_yaml(edge_list)
# Out:
# direct neighbours for each node:
# {1: [7, 6, 5, 4, 2], 2: [4, 3, 1], 3: [10, 8, 7, 6, 5, 4, 2], 4: [6, 3, 2, 1], 5: [7, 3, 1], 6: [10, 4, 3, 1], 7: [8, 5, 3, 1], 8: [7, 3], 10: [6, 3]}

# %%
# specify which IP addresses should be used for the different containers in "ip_configuration.yml"
with open("ip_configuration.yml",'r') as file_ip:
    dict_ip = yaml.safe_load(file_ip)
    print("provided IP configuration for a graph of up to 10 nodes:")
    print(dict_ip)
# Out:
# provided IP configuration for a graph of up to 10 nodes:
# {1: '172.20.0.11', 2: '172.20.0.12', 3: '172.20.0.13', 4: '172.20.0.14', 5: '172.20.0.15', 6: '172.20.0.16', 7: '172.20.0.17', 8: '172.20.0.18', 9: '172.20.0.19', 10: '172.20.0.20', 'subnet': '172.20.0.0/24'}

# %%
#Setup which port should be used for the gRPC communication between the nodes
PORT = 50051

# setup each node as docker container by generating a docker-compose file
dfs_con.write_docker_compose_yml(edge_list, PORT)
# Out:
# Initialization of Node 1:
# {'build': {'context': '.', 'args': {'PORT': 50051, 'NODE_ID': 1}}, 'networks': {'frontend': {'ipv4_address': '172.20.0.11'}}, 'command': "/bin/sh -c 'python3 dfs_server.py'", 'container_name': 'node1', 'volumes': ['./output:/grpc-docker/ddfs/output']}

# %%
# build docker images of each Node according to generated docker-compose.yml file
process = subprocess.Popen(['docker-compose', 'build'], stdout=subprocess.PIPE, shell=True)
stdout = process.communicate()[0]
print(stdout.decode('utf-8'))
# Out:
# #1 [grpc_docker-n6 internal] load build definition from Dockerfile
# #1 transferring dockerfile: 32B done
# #1 DONE 0.0s
#
# #2 [grpc_docker-n1 internal] load build definition from Dockerfile
# #2 transferring dockerfile: 32B done
# #2 DONE 0.0s
#
# #3 [grpc_docker-n3 internal] load build definition from Dockerfile
# #3 transferring dockerfile: 32B done
# #3 DONE 0.0s
#
# #4 [grpc_docker-n8 internal] load build definition from Dockerfile
# #4 transferring dockerfile: 32B done
# #4 DONE 0.0s
#
# #5 [grpc_docker-n10 internal] load build definition from Dockerfile
# #5 transferring dockerfile: 32B done
# #5 DONE 0.0s
#
# #6 [grpc_docker-n7 internal] load build definition from Dockerfile
# #6 transferring dockerfile: 32B done
# #6 DONE 0.0s
#
# #7 [grpc_docker-n5 internal] load build definition from Dockerfile
# #7 transferring dockerfile: 32B done
# #7 DONE 0.0s
#
# #8 [grpc_docker-n4 internal] load build definition from Dockerfile
# #8 transferring dockerfile: 32B done
# #8 DONE 0.0s
#
# #9 [grpc_docker-n2 internal] load build definition from Dockerfile
# #9 transferring dockerfile: 32B done
# #9 DONE 0.0s
#
# #10 [grpc_docker-n6 internal] load .dockerignore
# #10 transferring context: 2B done
# #10 DONE 0.0s
#
# #11 [grpc_docker-n3 internal] load .dockerignore
# #11 transferring context: 2B done
# #11 DONE 0.0s
#
# #12 [grpc_docker-n1 internal] load .dockerignore
# #12 transferring context: 2B done
# #12 DONE 0.0s
#
# #13 [grpc_docker-n10 internal] load .dockerignore
# #13 transferring context: 2B done
# #13 DONE 0.0s
#
# #14 [grpc_docker-n8 internal] load .dockerignore
# #14 transferring context: 2B done
# #14 DONE 0.0s
#
# #15 [grpc_docker-n4 internal] load .dockerignore
# #15 transferring context: 2B done
# #15 DONE 0.0s
#
# #16 [grpc_docker-n2 internal] load .dockerignore
# #16 transferring context: 2B done
# #16 DONE 0.0s
#
# #17 [grpc_docker-n7 internal] load .dockerignore
# #17 transferring context: 2B done
# #17 DONE 0.0s
#
# #18 [grpc_docker-n5 internal] load .dockerignore
# #18 transferring context: 2B done
# #18 DONE 0.0s
#
# #19 [grpc_docker-n10 internal] load metadata for docker.io/library/ubuntu:latest
# #19 DONE 0.0s
#
# #20 [grpc_docker-n10 1/8] FROM docker.io/library/ubuntu:latest
# #20 DONE 0.0s
#
# #21 [grpc_docker-n6 internal] load build context
# #21 transferring context: 42.91kB done
# #21 DONE 0.0s
#
# #22 [grpc_docker-n6 2/8] RUN apt-get update && apt-get install -y python3 python3-pip
# #22 CACHED
#
# #23 [grpc_docker-n6 4/8] RUN pip3 install -r /requirements.txt
# #23 CACHED
#
# #24 [grpc_docker-n6 3/8] COPY ./requirements.txt /requirements.txt
# #24 CACHED
#
# #25 [grpc_docker-n6 5/8] RUN mkdir /grpc-docker
# #25 CACHED
#
# #26 [grpc_docker-n6 6/8] COPY . /grpc-docker
# #26 DONE 0.0s
#
# #27 [grpc_docker-n6 7/8] WORKDIR /grpc-docker/ddfs
# #27 DONE 0.0s
#
# #28 [grpc_docker-n6 8/8] RUN ["python3", "-m",  "grpc_tools.protoc" ,"-I." ,"--python_out=.",  "--pyi_out=.", "--grpc_python_out=.", "dfs.proto"]
# #28 ...
#
# #29 [grpc_docker-n10 internal] load build context
# #29 transferring context: 42.91kB done
# #29 DONE 0.0s
#
# #30 [grpc_docker-n10 6/8] COPY . /grpc-docker
# #30 CACHED
#
# #31 [grpc_docker-n10 5/8] RUN mkdir /grpc-docker
# #31 CACHED
#
# #32 [grpc_docker-n10 4/8] RUN pip3 install -r /requirements.txt
# #32 CACHED
#
# #33 [grpc_docker-n10 3/8] COPY ./requirements.txt /requirements.txt
# #33 CACHED
#
# #34 [grpc_docker-n10 7/8] WORKDIR /grpc-docker/ddfs
# #34 CACHED
#
# #35 [grpc_docker-n7 internal] load build context
# #35 transferring context: 42.91kB done
# #35 DONE 0.0s
#
# #36 [grpc_docker-n5 internal] load build context
# #36 transferring context: 42.91kB done
# #36 DONE 0.0s
#
# #37 [grpc_docker-n4 internal] load build context
# #37 transferring context: 42.91kB done
# #37 DONE 0.0s
#
# #38 [grpc_docker-n7 7/8] WORKDIR /grpc-docker/ddfs
# #38 CACHED
#
# #39 [grpc_docker-n7 4/8] RUN pip3 install -r /requirements.txt
# #39 CACHED
#
# #40 [grpc_docker-n7 5/8] RUN mkdir /grpc-docker
# #40 CACHED
#
# #41 [grpc_docker-n7 3/8] COPY ./requirements.txt /requirements.txt
# #41 CACHED
#
# #42 [grpc_docker-n7 6/8] COPY . /grpc-docker
# #42 CACHED
#
# #43 [grpc_docker-n5 6/8] COPY . /grpc-docker
# #43 CACHED
#
# #44 [grpc_docker-n5 5/8] RUN mkdir /grpc-docker
# #44 CACHED
#
# #45 [grpc_docker-n5 3/8] COPY ./requirements.txt /requirements.txt
# #45 CACHED
#
# #46 [grpc_docker-n5 4/8] RUN pip3 install -r /requirements.txt
# #46 CACHED
#
# #47 [grpc_docker-n5 7/8] WORKDIR /grpc-docker/ddfs
# #47 CACHED
#
# #48 [grpc_docker-n2 internal] load build context
# #48 transferring context: 42.91kB done
# #48 DONE 0.0s
#
# #49 [grpc_docker-n4 5/8] RUN mkdir /grpc-docker
# #49 CACHED
#
# #50 [grpc_docker-n4 6/8] COPY . /grpc-docker
# #50 CACHED
#
# #51 [grpc_docker-n4 7/8] WORKDIR /grpc-docker/ddfs
# #51 CACHED
#
# #52 [grpc_docker-n4 3/8] COPY ./requirements.txt /requirements.txt
# #52 CACHED
#
# #53 [grpc_docker-n4 4/8] RUN pip3 install -r /requirements.txt
# #53 CACHED
#
# #19 [grpc_docker-n3 internal] load metadata for docker.io/library/ubuntu:latest
# #19 DONE 0.0s
#
# #54 [grpc_docker-n2 6/8] COPY . /grpc-docker
# #54 CACHED
#
# #55 [grpc_docker-n2 3/8] COPY ./requirements.txt /requirements.txt
# #55 CACHED
#
# #56 [grpc_docker-n2 5/8] RUN mkdir /grpc-docker
# #56 CACHED
#
# #57 [grpc_docker-n2 4/8] RUN pip3 install -r /requirements.txt
# #57 CACHED
#
# #58 [grpc_docker-n2 7/8] WORKDIR /grpc-docker/ddfs
# #58 CACHED
#
# #20 [grpc_docker-n1 1/8] FROM docker.io/library/ubuntu:latest
# #20 DONE 0.0s
#
# #22 [grpc_docker-n4 2/8] RUN apt-get update && apt-get install -y python3 python3-pip
# #22 CACHED
#
# #59 [grpc_docker-n3 internal] load build context
# #59 transferring context: 42.91kB done
# #59 DONE 0.0s
#
# #60 [grpc_docker-n3 5/8] RUN mkdir /grpc-docker
# #60 CACHED
#
# #61 [grpc_docker-n3 6/8] COPY . /grpc-docker
# #61 CACHED
#
# #62 [grpc_docker-n3 4/8] RUN pip3 install -r /requirements.txt
# #62 CACHED
#
# #63 [grpc_docker-n3 7/8] WORKDIR /grpc-docker/ddfs
# #63 CACHED
#
# #64 [grpc_docker-n3 3/8] COPY ./requirements.txt /requirements.txt
# #64 CACHED
#
# #65 [grpc_docker-n1 internal] load build context
# #65 transferring context: 42.91kB done
# #65 DONE 0.0s
#
# #66 [grpc_docker-n8 internal] load build context
# #66 transferring context: 42.91kB done
# #66 DONE 0.0s
#
# #20 [grpc_docker-n3 1/8] FROM docker.io/library/ubuntu:latest
# #20 DONE 0.0s
#
# #67 [grpc_docker-n1 3/8] COPY ./requirements.txt /requirements.txt
# #67 CACHED
#
# #68 [grpc_docker-n1 5/8] RUN mkdir /grpc-docker
# #68 CACHED
#
# #69 [grpc_docker-n1 4/8] RUN pip3 install -r /requirements.txt
# #69 CACHED
#
# #70 [grpc_docker-n1 6/8] COPY . /grpc-docker
# #70 CACHED
#
# #71 [grpc_docker-n1 7/8] WORKDIR /grpc-docker/ddfs
# #71 CACHED
#
# #72 [grpc_docker-n8 4/8] RUN pip3 install -r /requirements.txt
# #72 CACHED
#
# #73 [grpc_docker-n8 6/8] COPY . /grpc-docker
# #73 CACHED
#
# #74 [grpc_docker-n8 3/8] COPY ./requirements.txt /requirements.txt
# #74 CACHED
#
# #75 [grpc_docker-n8 5/8] RUN mkdir /grpc-docker
# #75 CACHED
#
# #76 [grpc_docker-n8 7/8] WORKDIR /grpc-docker/ddfs
# #76 CACHED
#
# #22 [grpc_docker-n8 2/8] RUN apt-get update && apt-get install -y python3 python3-pip
# #22 CACHED
#
# #77 [grpc_docker-n3 8/8] RUN ["python3", "-m",  "grpc_tools.protoc" ,"-I." ,"--python_out=.",  "--pyi_out=.", "--grpc_python_out=.", "dfs.proto"]
# #77 ...
#
# #78 [grpc_docker-n10 8/8] RUN ["python3", "-m",  "grpc_tools.protoc" ,"-I." ,"--python_out=.",  "--pyi_out=.", "--grpc_python_out=.", "dfs.proto"]
# #78 DONE 0.7s
#
# #28 [grpc_docker-n6 8/8] RUN ["python3", "-m",  "grpc_tools.protoc" ,"-I." ,"--python_out=.",  "--pyi_out=.", "--grpc_python_out=.", "dfs.proto"]
# #28 DONE 0.7s
#
# #79 [grpc_docker-n6] exporting to image
# #79 exporting layers 0.0s done
# #79 writing image sha256:850ed07c1288a97ffe91eca3c609a8f84cfa795c37c0ff9c9cd7bd80f2d5abdd done
# #79 naming to docker.io/library/grpc_docker-n10 done
# #79 writing image sha256:549df17feb8580f6a346627436a5774f707bf753f0bbce2d7b854225d3a95f76 done
# #79 naming to docker.io/library/grpc_docker-n6 done
# #79 DONE 0.1s
#
# #80 [grpc_docker-n1 8/8] RUN ["python3", "-m",  "grpc_tools.protoc" ,"-I." ,"--python_out=.",  "--pyi_out=.", "--grpc_python_out=.", "dfs.proto"]
# #80 ...
#
# #81 [grpc_docker-n5 8/8] RUN ["python3", "-m",  "grpc_tools.protoc" ,"-I." ,"--python_out=.",  "--pyi_out=.", "--grpc_python_out=.", "dfs.proto"]
# #81 DONE 1.2s
#
# #79 [grpc_docker-n5] exporting to image
# #79 exporting layers done
# #79 writing image sha256:ff103861a9a98abed3f8f627c20b658d11a5607b398d5600eebc61fa42266bd1 done
# #79 naming to docker.io/library/grpc_docker-n5 done
# #79 DONE 0.1s
#
# #82 [grpc_docker-n4 8/8] RUN ["python3", "-m",  "grpc_tools.protoc" ,"-I." ,"--python_out=.",  "--pyi_out=.", "--grpc_python_out=.", "dfs.proto"]
# #82 DONE 1.3s
#
# #79 [grpc_docker-n4] exporting to image
# #79 exporting layers done
# #79 writing image sha256:29cffb919178452907d3b645888b6a394d44af4f6cc02f43c2bf070287d46874 done
# #79 naming to docker.io/library/grpc_docker-n4 done
# #79 DONE 0.1s
#
# #83 [grpc_docker-n8 8/8] RUN ["python3", "-m",  "grpc_tools.protoc" ,"-I." ,"--python_out=.",  "--pyi_out=.", "--grpc_python_out=.", "dfs.proto"]
# #83 ...
#
# #84 [grpc_docker-n2 8/8] RUN ["python3", "-m",  "grpc_tools.protoc" ,"-I." ,"--python_out=.",  "--pyi_out=.", "--grpc_python_out=.", "dfs.proto"]
# #84 DONE 1.9s
#
# #85 [grpc_docker-n7 8/8] RUN ["python3", "-m",  "grpc_tools.protoc" ,"-I." ,"--python_out=.",  "--pyi_out=.", "--grpc_python_out=.", "dfs.proto"]
# #85 DONE 2.0s
#
# #79 [grpc_docker-n7] exporting to image
# #79 exporting layers done
# #79 writing image sha256:f7d89500d9de45ed2aa228b10c7f98eee5370396a86053a92724af49caf8fef7 done
# #79 naming to docker.io/library/grpc_docker-n2 done
# #79 writing image sha256:0cd3a890e40b6418759649f79f9009ce3e215d31c2720a94c5864f6f4d901a79 done
# #79 naming to docker.io/library/grpc_docker-n7 done
# #79 DONE 0.2s
#
# #83 [grpc_docker-n8 8/8] RUN ["python3", "-m",  "grpc_tools.protoc" ,"-I." ,"--python_out=.",  "--pyi_out=.", "--grpc_python_out=.", "dfs.proto"]
# #83 DONE 2.0s
#
# #77 [grpc_docker-n3 8/8] RUN ["python3", "-m",  "grpc_tools.protoc" ,"-I." ,"--python_out=.",  "--pyi_out=.", "--grpc_python_out=.", "dfs.proto"]
# #77 ...
#
# #79 [grpc_docker-n8] exporting to image
# #79 exporting layers done
# #79 writing image sha256:9a144b3cf9f8c0ef216fa9113058f12b4823e9c4b83aa24a8573edb3e2a99d73 done
# #79 naming to docker.io/library/grpc_docker-n8 done
# #79 DONE 0.2s
#
# #77 [grpc_docker-n3 8/8] RUN ["python3", "-m",  "grpc_tools.protoc" ,"-I." ,"--python_out=.",  "--pyi_out=.", "--grpc_python_out=.", "dfs.proto"]
# #77 DONE 2.6s
#
# #80 [grpc_docker-n1 8/8] RUN ["python3", "-m",  "grpc_tools.protoc" ,"-I." ,"--python_out=.",  "--pyi_out=.", "--grpc_python_out=.", "dfs.proto"]
# #80 ...
#
# #79 [grpc_docker-n3] exporting to image
# #79 exporting layers 0.0s done
# #79 writing image sha256:85528e61ccfd490bcd9ba21350eae41be0e911ec7793c2319ad0bdec0a9025ae done
# #79 naming to docker.io/library/grpc_docker-n3 done
# #79 DONE 0.2s
#
# #80 [grpc_docker-n1 8/8] RUN ["python3", "-m",  "grpc_tools.protoc" ,"-I." ,"--python_out=.",  "--pyi_out=.", "--grpc_python_out=.", "dfs.proto"]
# #80 DONE 2.8s
#
# #79 [grpc_docker-n1] exporting to image
# #79 exporting layers 0.0s done
# #79 writing image sha256:bf0b1df3096ad1d49777e1cb6ecfbf0f4caf5a61870f2bf2533457406f442432 done
# #79 naming to docker.io/library/grpc_docker-n1 done
# #79 DONE 0.2s

# %%
# start all created docker images as docker containers
# the protocol buffers are being built with start up
# the required code for DDFS is launched with start up (dfs_server.py)
process = subprocess.Popen(['docker-compose', 'up', '-d'], stdout=subprocess.PIPE, shell=True)
stdout = process.communicate()[0]
print(stdout.decode('utf-8'))

# %%
# start the DDFS on the root node
ROOT = 1
# enter the desired docker container and run dfs_client.py which will start the DDFS with the current node as root
process = subprocess.Popen(['docker', 'exec', 'node{}'.format(ROOT), 'python3', 'dfs_client.py'], stdout=subprocess.PIPE, shell=True)
stdout = process.communicate()[0]
print(stdout.decode('utf-8'))
# Out:
# Root:  1
# Will try to greet world ...
# Connected to server: Hello, 1! from 1 successfully.
# Greeted Neighbour: Hello, 1! from 2
# Child: 10 Parent: 6
# Child: 6 Parent: 4
# Child: 8 Parent: 7
# Child: 7 Parent: 5
# Child: 4 Parent: 3
# Child: 5 Parent: 3
# Child: 3 Parent: 2
# Child: 2 Parent: 1

# %%
#plot the minimum spanning tree (saved in output/mst.png)
plt.imshow(plt.imread("../output/mst.png"))
plt.show()
